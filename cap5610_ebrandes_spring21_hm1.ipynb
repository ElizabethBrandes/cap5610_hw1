# %%
import pandas as pd

# %%
train_df = pd.read_csv('../data/train.csv')

# %%
train_df.shape
# Out:
# (891, 12)

# %%
train_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    object
#  5   Age          714 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Cabin        204 non-null    object
#  11  Embarked     889 non-null    object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 83.7+ KB

# %%
train_df.dtypes
# Out:
# PassengerId      int64
# Survived         int64
# Pclass           int64
# Name            object
# Sex             object
# Age            float64
# SibSp            int64
# Parch            int64
# Ticket          object
# Fare           float64
# Cabin           object
# Embarked        object
# dtype: object

# %%
train_df.describe(include=["object"])
# Out:
#                                Name   Sex Ticket        Cabin Embarked
# count                           891   891    891          204      889
# unique                          891     2    681          147        3
# top     Futrelle, Mr. Jacques Heath  male   1601  C23 C25 C27        S
# freq                              1   577      7            4      644

# %%
train_df.describe()
# Out:
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   891.000000  891.000000  891.000000  714.000000  891.000000
# mean    446.000000    0.383838    2.308642   29.699118    0.523008
# std     257.353842    0.486592    0.836071   14.526497    1.102743
# min       1.000000    0.000000    1.000000    0.420000    0.000000
# 25%     223.500000    0.000000    2.000000   20.125000    0.000000
# 50%     446.000000    0.000000    3.000000   28.000000    0.000000
# 75%     668.500000    1.000000    3.000000   38.000000    1.000000
# max     891.000000    1.000000    3.000000   80.000000    8.000000
#
#             Parch        Fare
# count  891.000000  891.000000
# mean     0.381594   32.204208
# std      0.806057   49.693429
# min      0.000000    0.000000
# 25%      0.000000    7.910400
# 50%      0.000000   14.454200
# 75%      0.000000   31.000000
# max      6.000000  512.329200

# %%
categorical_columns = train_df[['Survived','Pclass','Sex','Embarked']]
cat_df = categorical_columns.copy()
cat_df = cat_df.astype({'Survived':object, 'Pclass':object})
cat_df.describe(include='all')
# Out:
#         Survived  Pclass   Sex Embarked
# count        891     891   891      889
# unique         2       3     2        3
# top            0       3  male        S
# freq         549     491   577      644

# %%
missing_df = (len(train_df.index) - train_df.count()).to_frame()
missing_df.columns = ['MissingValueCount']
missing_df
# Out:
#              MissingValueCount
# PassengerId                  0
# Survived                     0
# Pclass                       0
# Name                         0
# Sex                          0
# Age                        177
# SibSp                        0
# Parch                        0
# Ticket                       0
# Fare                         0
# Cabin                      687
# Embarked                     2

# %%
missing_df2 = (train_df.isnull().sum()).to_frame()
missing_df2.columns = ['MissingSum']
missing_df2
# Out:
#              MissingSum
# PassengerId           0
# Survived              0
# Pclass                0
# Name                  0
# Sex                   0
# Age                 177
# SibSp                 0
# Parch                 0
# Ticket                0
# Fare                  0
# Cabin               687
# Embarked              2

# %%
train_df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
train_df.head(891)
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
train_df.corr(method='pearson')
# Out:
#              PassengerId  Survived    Pclass       Age     SibSp     Parch  \
# PassengerId     1.000000 -0.005007 -0.035144  0.036847 -0.057527 -0.001652
# Survived       -0.005007  1.000000 -0.338481 -0.077221 -0.035322  0.081629
# Pclass         -0.035144 -0.338481  1.000000 -0.369226  0.083081  0.018443
# Age             0.036847 -0.077221 -0.369226  1.000000 -0.308247 -0.189119
# SibSp          -0.057527 -0.035322  0.083081 -0.308247  1.000000  0.414838
# Parch          -0.001652  0.081629  0.018443 -0.189119  0.414838  1.000000
# Fare            0.012658  0.257307 -0.549500  0.096067  0.159651  0.216225
#
#                  Fare
# PassengerId  0.012658
# Survived     0.257307
# Pclass      -0.549500
# Age          0.096067
# SibSp        0.159651
# Parch        0.216225
# Fare         1.000000

# %%
train_df[["Pclass", "Survived"]].groupby(['Pclass'], as_index=False).agg(['mean', 'count'])
# Out:
#         Survived
#             mean count
# Pclass
# 1       0.629630   216
# 2       0.472826   184
# 3       0.242363   491

# %%
train_df[["Sex", "Survived"]].groupby(['Sex'], as_index=False).agg(['mean', 'count'])
# Out:
#         Survived
#             mean count
# Sex
# female  0.742038   314
# male    0.188908   577

# %%
train_df[['Survived','Age']].groupby('Survived').hist(column='Age')
# Out:
# Survived
# 0    [[AxesSubplot(0.125,0.125;0.775x0.755)]]
# 1    [[AxesSubplot(0.125,0.125;0.775x0.755)]]
# dtype: object

# %%
NonNullAge_df = train_df[pd.notnull(train_df['Age'])]
suvived_nonnullage_df = NonNullAge_df[NonNullAge_df['Survived'] == 1]
suvived_nonnullage_df.hist(column=['Age'], bins=range(90))
# Out:
# array([[<AxesSubplot:title={'center':'Age'}>]], dtype=object)

# %%
died_nonnullage_df = NonNullAge_df[NonNullAge_df['Survived'] == 0]
died_nonnullage_df.hist(column=['Age'], bins=range(90))
# Out:
# array([[<AxesSubplot:title={'center':'Age'}>]], dtype=object)

# %%
train_df[['Survived','Age','Pclass']].groupby(['Survived','Pclass']).hist(column='Age',bins=20)
# Out:
# Survived  Pclass
# 0         1         [[AxesSubplot(0.125,0.125;0.775x0.755)]]
#           2         [[AxesSubplot(0.125,0.125;0.775x0.755)]]
#           3         [[AxesSubplot(0.125,0.125;0.775x0.755)]]
# 1         1         [[AxesSubplot(0.125,0.125;0.775x0.755)]]
#           2         [[AxesSubplot(0.125,0.125;0.775x0.755)]]
#           3         [[AxesSubplot(0.125,0.125;0.775x0.755)]]
# dtype: object

# %%
ticket_cols = train_df[['Ticket']]
ticket_df = ticket_cols.copy()
ticket_dups = ticket_df.duplicated()
ticket_dups = ticketdups.
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 886    False
# 887    False
# 888     True
# 889    False
# 890    False
# Length: 891, dtype: bool

# %%
train_df.duplicated(subset='Ticket').sum()
# Out:
# 210

# %%
train_df.duplicated(subset='Ticket', )
